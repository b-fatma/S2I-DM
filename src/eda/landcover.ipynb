# %% [markdown]
# # EDA Land Cover

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent.parent))

from config import raw_files, processed_files

# %%
import xarray as xr
import os
import pandas as pd
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import rasterio
import geopandas
import seaborn as sns

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# ### Land Cover Data

# %%
from shapely import wkt

filepath = processed_files["landcover"]
df = pd.read_csv(filepath)

# Convert 'geometry' column from WKT string to shapely geometry
df['geometry'] = df['geometry'].apply(wkt.loads)

gdf = geopandas.GeoDataFrame(df, geometry='geometry')
gdf.set_crs(epsg=4326, inplace=True)
# Out:
#            ID  GRIDCODE          AREA       LCCCODE  \
# 0           4       210  6.228187e+06  7001 // 8001
# 1           2       210  6.242408e+06  7001 // 8001
# 2           1       210  1.482995e+06  7001 // 8001
# 3           8        50  4.590841e+08  21497-121340
# 4          13       210  6.371533e+06  7001 // 8001
# ...       ...       ...           ...           ...
# 438508  52055       201  1.646170e+05          6001
# 438509  52058       200  1.482200e+05          0011
# 438510  52057       201  2.797149e+06          6001
# 438511  52056       201  6.585450e+05          6001
# 438512  52059       201  5.812750e+05          6001
#
#                                                  geometry
# 0       POLYGON ((6.41528 37.08696, 6.43103 37.0855, 6...
# 1       POLYGON ((7.18084 37.07917, 7.17998 37.08091, ...
# 2       POLYGON ((7.37137 37.08194, 7.3709 37.08717, 7...
# 3       POLYGON ((6.12361 36.68472, 6.12361 36.69306, ...
# 4       POLYGON ((6.26181 37.02361, 6.26193 37.02514, ...
# ...                                                   ...
# 438508  POLYGON ((9.62361 30.27083, 9.62361 30.26806, ...
# 438509  POLYGON ((9.56891 30.2625, 9.57361 30.2625, 9....
# 438510  POLYGON ((9.57053 30.25694, 9.57083 30.25694, ...
# 438511  POLYGON ((9.62083 30.25972, 9.62083 30.25694, ...
# 438512  POLYGON ((9.60417 30.24628, 9.60417 30.25694, ...
#
# [438513 rows x 5 columns]

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 438513 entries, 0 to 438512
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   ID        438513 non-null  int64
#  1   GRIDCODE  438513 non-null  int64
#  2   AREA      438513 non-null  float64
#  3   LCCCODE   438513 non-null  object
#  4   geometry  438513 non-null  geometry
# dtypes: float64(1), geometry(1), int64(2), object(1)
# memory usage: 16.7+ MB

# %%
filepath = processed_files["landcover_legend"]
df = pd.read_csv(filepath)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LC           45 non-null     object
#  1   LPos         45 non-null     float64
#  2   LCCCode      45 non-null     object
#  3   LCCMode      45 non-null     float64
#  4   LCCLevel     45 non-null     object
#  5   LCCOwnLabel  45 non-null     object
#  6   LCCOwnDescr  0 non-null      float64
#  7   LCCLabel     47 non-null     object
#  8   MapCode      45 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 3.4+ KB

# %% [markdown]
# ## LCCCODE

# %%
gdf['LCCCODE'].value_counts()
# Out:
# LCCCODE
# 0011                                172221
# 6001                                 61857
# 20049 // 20058                       47560
# 0003 / 0004                          31891
# 6004                                 25951
# 0004 // 0003                         24856
# 20058                                24520
# 21446 // 21450-121340 / 21454        16002
# 11498                                14872
# 21450                                 8248
# 21518                                 5432
# 21497-121340                          2575
# 21499-121340                           818
# 11490 // 11494                         550
# 7001 // 8001                           538
# 21454 // 21446 // 21450                405
# 0010                                   145
# 21497-15045                             49
# 6020                                     8
# 21496-121340 // 21497-129401             8
# 41638-60686-R2 // 41898-60686-R2         6
# 21454 // 21465                           1
# Name: count, dtype: int64

# %%
df['LCCCode'].nunique(), gdf['LCCCODE'].nunique()
# Out:
# (45, 22)

# %% [markdown]
# ### Filter Relevant LCCCodes

# %%
df = df[df['LCCCode'].isin(np.unique(gdf['LCCCODE']))]
df['LCCCode'].nunique(), gdf['LCCCODE'].nunique()
# Out:
# (22, 22)

# %%
df.head()
# Out:
#                             LC  LPos LCCCode  LCCMode LCCLevel  \
# 7           0Dichotomous Phase   1.0    0010      0.0      B15
# 8           0Dichotomous Phase   1.0    0011      0.0      B16
# 9     1Consolidated Bare Areas   1.0    6001      0.0       A1
# 10  2Unconsolidated Bare Areas   1.0    6004      0.0       A2
# 11                       Error   1.0    6020      0.0    A5B13
#
#                                 LCCOwnLabel  LCCOwnDescr  \
# 7   Artficial surfaces and associated areas          NaN
# 8                                Bare areas          NaN
# 9                   Consolidated bare areas          NaN
# 10            Non - consolidated bare areas          NaN
# 11                            Salt hardpans          NaN
#
#                                              LCCLabel MapCode
# 7          Artificial Surfaces and Associated Area(s)     190
# 8                                        Bare Area(s)     200
# 9                            Consolidated Material(s)     201
# 10                         Unconsolidated Material(s)     202
# 11  Bare Soil And/Or Unconsolidated Material(s) Wi...     203

# %%
df.set_index('LCCCode')['LC']
# Out:
# LCCCode
# 0010                                        0Dichotomous Phase
# 0011                                        0Dichotomous Phase
# 6001                                  1Consolidated Bare Areas
# 6004                                2Unconsolidated Bare Areas
# 6020                                                     Error
# 7001 // 8001                                      9Mixed Class
# 41638-60686-R2 // 41898-60686-R2                  9Mixed Class
# 11498                                                    Error
# 11490 // 11494                                    9Mixed Class
# 0003 / 0004                                       9Mixed Class
# 0004 // 0003                                      9Mixed Class
# 21496-121340 // 21497-129401                      9Mixed Class
# 21497-121340                                             Error
# 21499-121340                                             Error
# 21497-15045                                              Error
# 21446 // 21450-121340 / 21454                     9Mixed Class
# 21454 // 21446 // 21450                           9Mixed Class
# 21450                                                    Error
# 21518                                                    Error
# 21454 // 21465                                    9Mixed Class
# 20049 // 20058                                    9Mixed Class
# 20058                                       6Sparse Vegetation
# Name: LC, dtype: object

# %% [markdown]
# ## Map Display

# %%
gdf.plot(column='LCCCODE', legend=False, figsize=(10, 10))
plt.title('Land Cover - Algeria & Tunisia')
plt.show()

# %% [markdown]
# ## Land Cover Distribution

# %%
sns.histplot(gdf, y='LCCCODE')
plt.title('Distribution of Land Cover')
plt.show()

# %%
df[(df['LCCCode'] == "0011") | (df['LCCCode'] == "6001")]
# Out:
#                          LC  LPos LCCCode  LCCMode LCCLevel  \
# 8        0Dichotomous Phase   1.0    0011      0.0      B16
# 9  1Consolidated Bare Areas   1.0    6001      0.0       A1
#
#                LCCOwnLabel  LCCOwnDescr                  LCCLabel MapCode
# 8               Bare areas          NaN              Bare Area(s)     200
# 9  Consolidated bare areas          NaN  Consolidated Material(s)     201

# %% [markdown]
# **Try LCCCode * Area to measure actual appearance frequency instead of simple frequency**
