# %% [markdown]
# # Landcover Data Preprocessing

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent.parent))

from config import raw_files, processed_files, pre_merge_files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import geopandas

# %%
from shapely import wkt

filepath = processed_files["landcover"]
df = pd.read_csv(filepath)

# Convert 'geometry' column from WKT string to shapely geometry
df['geometry'] = df['geometry'].apply(wkt.loads)

gdf = geopandas.GeoDataFrame(df, geometry='geometry')
gdf.set_crs(epsg=4326, inplace=True)
# Out:
#            ID  GRIDCODE          AREA       LCCCODE  \
# 0           4       210  6.228187e+06  7001 // 8001
# 1           2       210  6.242408e+06  7001 // 8001
# 2           1       210  1.482995e+06  7001 // 8001
# 3           8        50  4.590841e+08  21497-121340
# 4          13       210  6.371533e+06  7001 // 8001
# ...       ...       ...           ...           ...
# 438508  52055       201  1.646170e+05          6001
# 438509  52058       200  1.482200e+05          0011
# 438510  52057       201  2.797149e+06          6001
# 438511  52056       201  6.585450e+05          6001
# 438512  52059       201  5.812750e+05          6001
#
#                                                  geometry
# 0       POLYGON ((6.41528 37.08696, 6.43103 37.0855, 6...
# 1       POLYGON ((7.18084 37.07917, 7.17998 37.08091, ...
# 2       POLYGON ((7.37137 37.08194, 7.3709 37.08717, 7...
# 3       POLYGON ((6.12361 36.68472, 6.12361 36.69306, ...
# 4       POLYGON ((6.26181 37.02361, 6.26193 37.02514, ...
# ...                                                   ...
# 438508  POLYGON ((9.62361 30.27083, 9.62361 30.26806, ...
# 438509  POLYGON ((9.56891 30.2625, 9.57361 30.2625, 9....
# 438510  POLYGON ((9.57053 30.25694, 9.57083 30.25694, ...
# 438511  POLYGON ((9.62083 30.25972, 9.62083 30.25694, ...
# 438512  POLYGON ((9.60417 30.24628, 9.60417 30.25694, ...
#
# [438513 rows x 5 columns]

# %%
# gdf['centroid'] = gdf['geometry'].centroid

# gdf["longitude"] = gdf.centroid.map(lambda p: p.x)
# gdf["latitude"] = gdf.centroid.map(lambda p: p.y)

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 438513 entries, 0 to 438512
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   ID        438513 non-null  int64
#  1   GRIDCODE  438513 non-null  int64
#  2   AREA      438513 non-null  float64
#  3   LCCCODE   438513 non-null  object
#  4   geometry  438513 non-null  geometry
# dtypes: float64(1), geometry(1), int64(2), object(1)
# memory usage: 16.7+ MB

# %%
gdf['GRIDCODE'].value_counts()
# Out:
# GRIDCODE
# 200    172221
# 201     61857
# 150     47560
# 20      31891
# 202     25951
# 30      24856
# 151     24520
# 110     16002
# 14      14872
# 130      8248
# 134      5432
# 50       2575
# 70        818
# 16        550
# 210       538
# 120       405
# 190       145
# 100        49
# 203         8
# 41          8
# 170         6
# 140         1
# Name: count, dtype: int64

# %%
sns.barplot(gdf['LCCCODE'])
# Out:
# <Axes: ylabel='LCCCODE'>

# %%
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()

# gdf['lcccode_label'] = le.fit_transform(gdf['LCCCODE'])

# %%
gdf.head()
# Out:
#    ID  GRIDCODE          AREA       LCCCODE  \
# 0   4       210  6.228187e+06  7001 // 8001
# 1   2       210  6.242408e+06  7001 // 8001
# 2   1       210  1.482995e+06  7001 // 8001
# 3   8        50  4.590841e+08  21497-121340
# 4  13       210  6.371533e+06  7001 // 8001
#
#                                             geometry
# 0  POLYGON ((6.41528 37.08696, 6.43103 37.0855, 6...
# 1  POLYGON ((7.18084 37.07917, 7.17998 37.08091, ...
# 2  POLYGON ((7.37137 37.08194, 7.3709 37.08717, 7...
# 3  POLYGON ((6.12361 36.68472, 6.12361 36.69306, ...
# 4  POLYGON ((6.26181 37.02361, 6.26193 37.02514, ...

# %%
gdf[['LCCCODE', 'GRIDCODE']].value_counts()
# Out:
# LCCCODE                           GRIDCODE
# 0011                              200         172221
# 6001                              201          61857
# 20049 // 20058                    150          47560
# 0003 / 0004                       20           31891
# 6004                              202          25951
# 0004 // 0003                      30           24856
# 20058                             151          24520
# 21446 // 21450-121340 / 21454     110          16002
# 11498                             14           14872
# 21450                             130           8248
# 21518                             134           5432
# 21497-121340                      50            2575
# 21499-121340                      70             818
# 11490 // 11494                    16             550
# 7001 // 8001                      210            538
# 21454 // 21446 // 21450           120            405
# 0010                              190            145
# 21497-15045                       100             49
# 6020                              203              8
# 21496-121340 // 21497-129401      41               8
# 41638-60686-R2 // 41898-60686-R2  170              6
# 21454 // 21465                    140              1
# Name: count, dtype: int64

# %%
gdf.drop(columns=['ID', 'AREA', 'LCCCODE'], inplace=True)
gdf.head()
# Out:
#    GRIDCODE                                           geometry
# 0       210  POLYGON ((6.41528 37.08696, 6.43103 37.0855, 6...
# 1       210  POLYGON ((7.18084 37.07917, 7.17998 37.08091, ...
# 2       210  POLYGON ((7.37137 37.08194, 7.3709 37.08717, 7...
# 3        50  POLYGON ((6.12361 36.68472, 6.12361 36.69306, ...
# 4       210  POLYGON ((6.26181 37.02361, 6.26193 37.02514, ...

# %%
import shapely

gdf = gdf.copy()
gdf["geometry"] = shapely.to_wkt(gdf.geometry)

# gdf.to_csv("landcover.csv", index=False)
# Out:
# /tmp/ipykernel_6838/1552848752.py:4: UserWarning: Geometry column does not contain geometry.
#   gdf["geometry"] = shapely.to_wkt(gdf.geometry)

# %%
gdf.to_csv('../../data/premerge/landcover.csv', index=False)

# %% [markdown]
# manually assign codes to LCCCODEs
