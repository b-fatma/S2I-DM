# %% [markdown]
# <a href="https://colab.research.google.com/github/b-fatma/S2I-DM/blob/master/src/3_merge/v2/merge_2_add_soil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import pandas as pd
import csv
import sys
import geopandas as gpd
import shapely
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fire_landcover_elevation_path = '/content/drive/MyDrive/dm_fire_prediction/mergee/fire_landcover_elevation_no_binning.csv'
soil_path = '/content/drive/MyDrive/dm_fire_prediction/premerge/soil.csv'

# %%
df = pd.read_csv(fire_landcover_elevation_path)
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf.head()
# Out:
#    longitude  latitude  fire  GRIDCODE  elevation                  geometry
# 0    5.53337  35.70751     1     134.0     1898.0  POINT (5.53337 35.70751)
# 1    6.46961  32.13579     1     202.0      137.0  POINT (6.46961 32.13579)
# 2    6.97630  32.35563     1     202.0      125.0   POINT (6.9763 32.35563)
# 3    9.39581  28.19791     1     201.0      616.0  POINT (9.39581 28.19791)
# 4    9.49323  28.12826     1     201.0      589.0  POINT (9.49323 28.12826)

# %%
soil_df = pd.read_csv(soil_path)
soil_gdf = gpd.GeoDataFrame(soil_df, geometry=gpd.points_from_xy(soil_df.longitude, soil_df.latitude))
soil_gdf.head()
# Out:
#     latitude  longitude  COARSE  SAND  SILT  CLAY   BULK  REF_BULK  \
# 0  37.541655   8.948773     6.6  54.6  22.2  23.2  1.386     1.620
# 1  37.533318   8.915426    10.4  35.5  44.6  19.9  1.467     1.702
# 2  37.533318   8.923763    10.4  35.5  44.6  19.9  1.467     1.702
# 3  37.533318   8.932100    10.4  35.5  44.6  19.9  1.467     1.702
# 4  37.533318   8.940436    10.4  35.5  44.6  19.9  1.467     1.702
#
#    ORG_CARBON  PH_WATER  ...   TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  \
# 0      1.4092      5.94  ...  11.4  79.6       2.4  1.4         0.0     1.0
# 1      1.9662      5.45  ...   7.1  52.4      22.5  1.6         0.0     0.1
# 2      1.9662      5.45  ...   7.1  52.4      22.5  1.6         0.0     0.1
# 3      1.9662      5.45  ...   7.1  52.4      22.5  1.6         0.0     0.1
# 4      1.9662      5.45  ...   7.1  52.4      22.5  1.6         0.0     0.1
#
#    ELEC_COND  TEXTURE_USDA  TEXTURE_SOTER                  geometry
# 0        0.6          12.0              C  POINT (8.94877 37.54166)
# 1        NaN           9.0              M  POINT (8.91543 37.53332)
# 2        NaN           9.0              M  POINT (8.92376 37.53332)
# 3        NaN           9.0              M   POINT (8.9321 37.53332)
# 4        NaN           9.0              M  POINT (8.94044 37.53332)
#
# [5 rows x 25 columns]

# %%
soil_gdf.nunique()
# Out:
# latitude            1219
# longitude           2433
# COARSE               169
# SAND                 205
# SILT                 182
# CLAY                 179
# BULK                 219
# REF_BULK             237
# ORG_CARBON           282
# PH_WATER             217
# TOTAL_N              271
# CN_RATIO              65
# CEC_SOIL             163
# CEC_CLAY             224
# CEC_EFF              216
# TEB                  224
# BSAT                 134
# ALUM_SAT              18
# ESP                  115
# TCARBON_EQ           262
# GYPSUM               243
# ELEC_COND             61
# TEXTURE_USDA           6
# TEXTURE_SOTER          3
# geometry         1954594
# dtype: int64

# %%
soil_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1954594 entries, 0 to 1954593
# Data columns (total 25 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   latitude       float64
#  1   longitude      float64
#  2   COARSE         float64
#  3   SAND           float64
#  4   SILT           float64
#  5   CLAY           float64
#  6   BULK           float64
#  7   REF_BULK       float64
#  8   ORG_CARBON     float64
#  9   PH_WATER       float64
#  10  TOTAL_N        float64
#  11  CN_RATIO       float64
#  12  CEC_SOIL       float64
#  13  CEC_CLAY       float64
#  14  CEC_EFF        float64
#  15  TEB            float64
#  16  BSAT           float64
#  17  ALUM_SAT       float64
#  18  ESP            float64
#  19  TCARBON_EQ     float64
#  20  GYPSUM         float64
#  21  ELEC_COND      float64
#  22  TEXTURE_USDA   float64
#  23  TEXTURE_SOTER  object
#  24  geometry       geometry
# dtypes: float64(23), geometry(1), object(1)
# memory usage: 372.8+ MB

# %%
soil_gdf.dropna(inplace=True)
soil_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1380866 entries, 0 to 1954593
# Data columns (total 25 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   latitude       1380866 non-null  float64
#  1   longitude      1380866 non-null  float64
#  2   COARSE         1380866 non-null  float64
#  3   SAND           1380866 non-null  float64
#  4   SILT           1380866 non-null  float64
#  5   CLAY           1380866 non-null  float64
#  6   BULK           1380866 non-null  float64
#  7   REF_BULK       1380866 non-null  float64
#  8   ORG_CARBON     1380866 non-null  float64
#  9   PH_WATER       1380866 non-null  float64
#  10  TOTAL_N        1380866 non-null  float64
#  11  CN_RATIO       1380866 non-null  float64
#  12  CEC_SOIL       1380866 non-null  float64
#  13  CEC_CLAY       1380866 non-null  float64
#  14  CEC_EFF        1380866 non-null  float64
#  15  TEB            1380866 non-null  float64
#  16  BSAT           1380866 non-null  float64
#  17  ALUM_SAT       1380866 non-null  float64
#  18  ESP            1380866 non-null  float64
#  19  TCARBON_EQ     1380866 non-null  float64
#  20  GYPSUM         1380866 non-null  float64
#  21  ELEC_COND      1380866 non-null  float64
#  22  TEXTURE_USDA   1380866 non-null  float64
#  23  TEXTURE_SOTER  1380866 non-null  object
#  24  geometry       1380866 non-null  geometry
# dtypes: float64(23), geometry(1), object(1)
# memory usage: 273.9+ MB

# %%
# Perform nearest-neighbor join
joined = gdf.sjoin_nearest(
    soil_gdf,
    how='left'
)

joined
# Out:
#          longitude_left  latitude_left  fire  GRIDCODE  elevation  \
# 0              5.533370      35.707510     1     134.0     1898.0
# 1              6.469610      32.135790     1     202.0      137.0
# 2              6.976300      32.355630     1     202.0      125.0
# 3              9.395810      28.197910     1     201.0      616.0
# 4              9.493230      28.128260     1     201.0      589.0
# ...                 ...            ...   ...       ...        ...
# 1965252        9.825798      37.320199     0      30.0       84.0
# 1965253        9.834781      37.320199     0      30.0      145.0
# 1965254        9.843764      37.320199     0      30.0      136.0
# 1965255        9.852747      37.320199     0      30.0      160.0
# 1965256        9.861730      37.320199     0      30.0       36.0
#
#                          geometry  index_right  latitude_right  \
# 0        POINT (5.53337 35.70751)       171557       35.707501
# 1        POINT (6.46961 32.13579)       813308       32.139236
# 2         POINT (6.9763 32.35563)       775978       32.347663
# 3        POINT (9.39581 28.19791)      1691995       28.195803
# 4        POINT (9.49323 28.12826)      1709803       28.129107
# ...                           ...          ...             ...
# 1965252    POINT (9.8258 37.3202)          359       37.266532
# 1965253   POINT (9.83478 37.3202)          361       37.266532
# 1965254   POINT (9.84376 37.3202)          260       37.283206
# 1965255   POINT (9.85275 37.3202)          260       37.283206
# 1965256   POINT (9.86173 37.3202)          260       37.283206
#
#          longitude_right  COARSE  ...  CEC_EFF   TEB   BSAT  ALUM_SAT   ESP  \
# 0               5.530728    13.5  ...     29.0  24.0   81.5       0.0   3.0
# 1               6.472775     9.0  ...     37.0  37.0   99.0       0.0   4.0
# 2               6.997986    12.0  ...     30.0  30.0  100.0       0.0   3.0
# 3               9.398955    12.0  ...     30.0  30.0  100.0       0.0   3.0
# 4               9.490658    12.0  ...     30.0  30.0  100.0       0.0   3.0
# ...                  ...     ...  ...      ...   ...    ...       ...   ...
# 1965252         9.824126     6.2  ...     30.6  30.2   93.2       0.0  39.4
# 1965253         9.840799     6.2  ...     30.6  30.2   93.2       0.0  39.4
# 1965254         9.882483     6.2  ...     30.6  30.2   93.2       0.0  39.4
# 1965255         9.882483     6.2  ...     30.6  30.2   93.2       0.0  39.4
# 1965256         9.882483     6.2  ...     30.6  30.2   93.2       0.0  39.4
#
#          TCARBON_EQ  GYPSUM  ELEC_COND  TEXTURE_USDA  TEXTURE_SOTER
# 0              4.90    1.20        1.0           5.0              M
# 1              9.30    3.30        1.0          11.0              M
# 2              8.00    4.00        1.0          11.0              M
# 3              8.00    4.00        1.0          11.0              M
# 4              8.00    4.00        1.0          11.0              M
# ...             ...     ...        ...           ...            ...
# 1965252        9.48    4.02       10.0           5.0              M
# 1965253        9.48    4.02       10.0           5.0              M
# 1965254        9.48    4.02       10.0           5.0              M
# 1965255        9.48    4.02       10.0           5.0              M
# 1965256        9.48    4.02       10.0           5.0              M
#
# [1965257 rows x 31 columns]

# %%
joined.rename({'longitude_right': 'longitude_soil',
              'latitude_right': 'latitude_soil'}, axis=1, inplace=True)
joined.head()
# Out:
#    longitude_left  latitude_left  fire  GRIDCODE  elevation  \
# 0         5.53337       35.70751     1     134.0     1898.0
# 1         6.46961       32.13579     1     202.0      137.0
# 2         6.97630       32.35563     1     202.0      125.0
# 3         9.39581       28.19791     1     201.0      616.0
# 4         9.49323       28.12826     1     201.0      589.0
#
#                    geometry  index_right  latitude_soil  longitude_soil  \
# 0  POINT (5.53337 35.70751)       171557      35.707501        5.530728
# 1  POINT (6.46961 32.13579)       813308      32.139236        6.472775
# 2   POINT (6.9763 32.35563)       775978      32.347663        6.997986
# 3  POINT (9.39581 28.19791)      1691995      28.195803        9.398955
# 4  POINT (9.49323 28.12826)      1709803      28.129107        9.490658
#
#    COARSE  ...  CEC_EFF   TEB   BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  \
# 0    13.5  ...     29.0  24.0   81.5       0.0  3.0         4.9     1.2
# 1     9.0  ...     37.0  37.0   99.0       0.0  4.0         9.3     3.3
# 2    12.0  ...     30.0  30.0  100.0       0.0  3.0         8.0     4.0
# 3    12.0  ...     30.0  30.0  100.0       0.0  3.0         8.0     4.0
# 4    12.0  ...     30.0  30.0  100.0       0.0  3.0         8.0     4.0
#
#    ELEC_COND  TEXTURE_USDA  TEXTURE_SOTER
# 0        1.0           5.0              M
# 1        1.0          11.0              M
# 2        1.0          11.0              M
# 3        1.0          11.0              M
# 4        1.0          11.0              M
#
# [5 rows x 31 columns]

# %%
joined.drop(columns=['geometry', 'index_right'], inplace=True)
joined.head()
# Out:
#    longitude_left  latitude_left  fire  GRIDCODE  elevation  latitude_soil  \
# 0         5.53337       35.70751     1     134.0     1898.0      35.707501
# 1         6.46961       32.13579     1     202.0      137.0      32.139236
# 2         6.97630       32.35563     1     202.0      125.0      32.347663
# 3         9.39581       28.19791     1     201.0      616.0      28.195803
# 4         9.49323       28.12826     1     201.0      589.0      28.129107
#
#    longitude_soil  COARSE  SAND  SILT  ...  CEC_EFF   TEB   BSAT  ALUM_SAT  \
# 0        5.530728    13.5  41.0  34.5  ...     29.0  24.0   81.5       0.0
# 1        6.472775     9.0  55.0  30.0  ...     37.0  37.0   99.0       0.0
# 2        6.997986    12.0  57.0  27.0  ...     30.0  30.0  100.0       0.0
# 3        9.398955    12.0  57.0  27.0  ...     30.0  30.0  100.0       0.0
# 4        9.490658    12.0  57.0  27.0  ...     30.0  30.0  100.0       0.0
#
#    ESP  TCARBON_EQ  GYPSUM  ELEC_COND  TEXTURE_USDA  TEXTURE_SOTER
# 0  3.0         4.9     1.2        1.0           5.0              M
# 1  4.0         9.3     3.3        1.0          11.0              M
# 2  3.0         8.0     4.0        1.0          11.0              M
# 3  3.0         8.0     4.0        1.0          11.0              M
# 4  3.0         8.0     4.0        1.0          11.0              M
#
# [5 rows x 29 columns]

# %%
joined.rename({'longitude_left': 'longitude',
              'latitude_left': 'latitude'}, axis=1, inplace=True)
joined.head()
# Out:
#    longitude  latitude  fire  GRIDCODE  elevation  latitude_soil  \
# 0    5.53337  35.70751     1     134.0     1898.0      35.707501
# 1    6.46961  32.13579     1     202.0      137.0      32.139236
# 2    6.97630  32.35563     1     202.0      125.0      32.347663
# 3    9.39581  28.19791     1     201.0      616.0      28.195803
# 4    9.49323  28.12826     1     201.0      589.0      28.129107
#
#    longitude_soil  COARSE  SAND  SILT  ...  CEC_EFF   TEB   BSAT  ALUM_SAT  \
# 0        5.530728    13.5  41.0  34.5  ...     29.0  24.0   81.5       0.0
# 1        6.472775     9.0  55.0  30.0  ...     37.0  37.0   99.0       0.0
# 2        6.997986    12.0  57.0  27.0  ...     30.0  30.0  100.0       0.0
# 3        9.398955    12.0  57.0  27.0  ...     30.0  30.0  100.0       0.0
# 4        9.490658    12.0  57.0  27.0  ...     30.0  30.0  100.0       0.0
#
#    ESP  TCARBON_EQ  GYPSUM  ELEC_COND  TEXTURE_USDA  TEXTURE_SOTER
# 0  3.0         4.9     1.2        1.0           5.0              M
# 1  4.0         9.3     3.3        1.0          11.0              M
# 2  3.0         8.0     4.0        1.0          11.0              M
# 3  3.0         8.0     4.0        1.0          11.0              M
# 4  3.0         8.0     4.0        1.0          11.0              M
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Saving the Output

# %%
output_path = '/content/drive/MyDrive/dm_fire_prediction/mergee/fire_landcover_elevation_no_binning_soil_no_na.csv'

joined.to_csv(output_path, index=False)
