# %% [markdown]
# <a href="https://colab.research.google.com/github/b-fatma/S2I-DM/blob/master/src/merge/merge_3_add_climate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import pandas as pd
import csv
import sys
import geopandas as gpd
import shapely
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fire_landcover_elevation_soil_path = '/content/drive/MyDrive/dm_fire_prediction/merge/fire_landcover_elevation_soil_no_na.csv'
climate_path = '/content/drive/MyDrive/dm_fire_prediction/premerge/climate_seasonal.csv'

# %%
df = pd.read_csv(fire_landcover_elevation_soil_path)
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf.head()
# Out:
#    longitude  latitude  fire  lcccode_label  elevation_ED_smoothed_by_mean  \
# 0    5.53337  35.70751     1           16.0                         1787.5
# 1    6.46961  32.13579     1           19.0                         -280.0
# 2    6.97630  32.35563     1           19.0                         -280.0
# 3    9.39581  28.19791     1           18.0                          581.0
# 4    9.49323  28.12826     1           18.0                          581.0
#
#    latitude_soil  longitude_soil  COARSE  SAND  SILT  ...   TEB   BSAT  \
# 0      35.707501        5.530728    13.5  41.0  34.5  ...  24.0   81.5
# 1      32.139236        6.472775     9.0  55.0  30.0  ...  37.0   99.0
# 2      32.347663        6.997986    12.0  57.0  27.0  ...  30.0  100.0
# 3      28.195803        9.398955    12.0  57.0  27.0  ...  30.0  100.0
# 4      28.129107        9.490658    12.0  57.0  27.0  ...  30.0  100.0
#
#    ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND  TEXTURE_USDA  TEXTURE_SOTER  \
# ...

# %%
gdf.describe()
# Out:
#           longitude      latitude          fire  lcccode_label  \
# count  1.965257e+06  1.965257e+06  1.965257e+06   1.964326e+06
# mean   3.225199e+00  3.165267e+01  6.484139e-03   1.241255e+01
# std    4.550053e+00  2.793161e+00  8.026268e-02   7.459300e+00
# min   -8.118050e+00  2.722278e+01  0.000000e+00   0.000000e+00
# 25%   -5.567033e-02  2.915848e+01  0.000000e+00   3.000000e+00
# 50%    3.564540e+00  3.145386e+01  0.000000e+00   1.800000e+01
# 75%    7.005088e+00  3.405979e+01  0.000000e+00   1.900000e+01
# max    1.111039e+01  3.732346e+01  1.000000e+00   2.100000e+01
#
#        elevation_ED_smoothed_by_mean  latitude_soil  longitude_soil  \
# count                   1.965257e+06   1.965257e+06    1.965257e+06
# mean                    5.404178e+02   3.166079e+01    3.225104e+00
# std                     7.311260e+02   2.791774e+00    4.557507e+00
# min                    -2.800000e+02   2.721203e+01   -8.116441e+00
# ...

# %%
climate_df = pd.read_csv(climate_path)
climate_gdf = gpd.GeoDataFrame(climate_df, geometry=gpd.points_from_xy(climate_df.longitude, climate_df.latitude))
climate_gdf.head()
# Out:
#    longitude   latitude  prec_autumn  prec_spring  prec_summer  prec_winter  \
# 0     -8.625  27.291667       65.250        2.000          3.4     6.525000
# 1     -8.625  27.375000       66.250        2.000          3.4     7.250000
# 2     -8.625  27.458333       67.025        2.000          3.5     8.775001
# 3     -8.625  27.541667       68.175        1.900          3.5     8.975000
# 4     -8.625  27.625000       68.425        2.175          3.5     9.800000
#
#    tmax_autumn  tmax_spring  tmax_summer  tmax_winter  tmin_autumn  \
# 0    31.333334    30.750000    39.666668    22.916666    18.333334
# 1    31.333334    30.416666    39.416668    22.750000    18.333334
# 2    31.333334    30.500000    39.500000    22.666666    18.083334
# 3    31.333334    30.333334    39.333332    22.333334    17.666666
# 4    31.000000    30.333334    39.333332    22.333334    17.666666
#
#    tmin_spring  tmin_summer  tmin_winter                 geometry
# ...

# %%
joined = gdf.sjoin_nearest(
    climate_gdf,
    how='left'
)

joined
# Out:
#          longitude_left  latitude_left  fire  lcccode_label  \
# 0              5.533370      35.707510     1           16.0
# 1              6.469610      32.135790     1           19.0
# 2              6.976300      32.355630     1           19.0
# 3              9.395810      28.197910     1           18.0
# 4              9.493230      28.128260     1           18.0
# ...                 ...            ...   ...            ...
# 1965252        9.825798      37.320199     0            1.0
# 1965253        9.834781      37.320199     0            1.0
# 1965254        9.843764      37.320199     0            1.0
# 1965255        9.852747      37.320199     0            1.0
# 1965256        9.861730      37.320199     0            1.0
#
#          elevation_ED_smoothed_by_mean  latitude_soil  longitude_soil  COARSE  \
# 0                               1787.5      35.707501        5.530728    13.5
# 1                               -280.0      32.139236        6.472775     9.0
# ...

# %%
joined.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1965257 entries, 0 to 1965256
# Data columns (total 45 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   longitude_left                 float64
#  1   latitude_left                  float64
#  2   fire                           int64
#  3   lcccode_label                  float64
#  4   elevation_ED_smoothed_by_mean  float64
#  5   latitude_soil                  float64
#  6   longitude_soil                 float64
#  7   COARSE                         float64
#  8   SAND                           float64
#  9   SILT                           float64
#  10  CLAY                           float64
#  11  BULK                           float64
#  12  REF_BULK                       float64
#  13  ORG_CARBON                     float64
#  14  PH_WATER                       float64
#  15  TOTAL_N                        float64
#  16  CN_RATIO                       float64
# ...

# %%
joined.drop(columns=['geometry', 'index_right', 'longitude_right', 'latitude_right'], inplace=True)
joined.rename({'longitude_left': 'longitude',
              'latitude_left': 'latitude'}, axis=1, inplace=True)
joined.head()
# Out:
#    longitude  latitude  fire  lcccode_label  elevation_ED_smoothed_by_mean  \
# 0    5.53337  35.70751     1           16.0                         1787.5
# 1    6.46961  32.13579     1           19.0                         -280.0
# 2    6.97630  32.35563     1           19.0                         -280.0
# 3    9.39581  28.19791     1           18.0                          581.0
# 4    9.49323  28.12826     1           18.0                          581.0
#
#    latitude_soil  longitude_soil  COARSE  SAND  SILT  ...  prec_summer  \
# 0      35.707501        5.530728    13.5  41.0  34.5  ...       19.675
# 1      32.139236        6.472775     9.0  55.0  30.0  ...        2.300
# 2      32.347663        6.997986    12.0  57.0  27.0  ...        2.200
# 3      28.195803        9.398955    12.0  57.0  27.0  ...        1.000
# 4      28.129107        9.490658    12.0  57.0  27.0  ...        1.000
#
#    prec_winter  tmax_autumn  tmax_spring  tmax_summer  tmax_winter  \
# ...

# %%
joined.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 1965257 entries, 0 to 1965256
# Data columns (total 41 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   longitude                      float64
#  1   latitude                       float64
#  2   fire                           int64
#  3   lcccode_label                  float64
#  4   elevation_ED_smoothed_by_mean  float64
#  5   latitude_soil                  float64
#  6   longitude_soil                 float64
#  7   COARSE                         float64
#  8   SAND                           float64
#  9   SILT                           float64
#  10  CLAY                           float64
#  11  BULK                           float64
#  12  REF_BULK                       float64
#  13  ORG_CARBON                     float64
#  14  PH_WATER                       float64
#  15  TOTAL_N                        float64
#  16  CN_RATIO                       float64
# ...

# %%
joined.isna().sum()
# Out:
# longitude                          0
# latitude                           0
# fire                               0
# lcccode_label                    931
# elevation_ED_smoothed_by_mean      0
# latitude_soil                      0
# longitude_soil                     0
# COARSE                             0
# SAND                               0
# SILT                               0
# CLAY                               0
# BULK                               0
# REF_BULK                           0
# ORG_CARBON                         0
# PH_WATER                           0
# TOTAL_N                            0
# CN_RATIO                           0
# CEC_SOIL                           0
# CEC_CLAY                           0
# CEC_EFF                            0
# TEB                                0
# BSAT                               0
# ALUM_SAT                           0
# ESP                                0
# TCARBON_EQ                         0
# ...

# %% [markdown]
# ## Saving the Output

# %%
output_path = '/content/drive/MyDrive/dm_fire_prediction/merge/fire_landcover_elevation_soil_no_na_climate.csv'

joined.to_csv(output_path, index=False)
